# %%
import pandas as pd
import os
import plotly.express as px
import plotly.graph_objects as go

# %%
sim_path = os.path.join("..","simulations","50_50")
scenario_01 = os.path.join("scenario_01")

# %%
cons_runs = pd.read_csv(os.path.join(sim_path,scenario_01,"sc_01_66_consecutiveRuns.txt"),
                        sep=" ")
cons_runs.head()
# Out:
#    group    id  chrom  nSNP      from        to  lengthBps
# 0      1  9402      1    38   1821510   5962634    4141124
# 1      1  9402      1    73   6072683  13504311    7431628
# 2      1  9402      1    26  14682924  17120188    2437264
# 3      1  9402      1    21  17701088  19349684    1648596
# 4      1  9402      1    22  24618671  26432675    1814004

# %%
candidates_metrics = pd.read_csv(os.path.join(sim_path,scenario_01,"candidates_metrics.txt"),
                        sep=" ")
candidates_metrics.head()
# Out:
#      ID sex     pheno       EBV        GV  solution      Fped        Fg  \
# 0  6704   F  4.583122  4.100254  2.985965  3.613491  0.031250  1.228771
# 1  6712   F  4.680363  4.100254  4.098994  3.409761  0.031250  1.296406
# 2  6720   F  4.951420  4.100254  3.327393  3.286090  0.025391  1.042126
# 3  6724   F  5.095029  4.100254  3.212567  3.403744  0.101562  1.154811
# 4  6726   F  5.410305  4.100254  3.238391  3.511174  0.046875  1.114135
#
#    Froh_genome  gen
# 0     0.260315   17
# 1     0.340589   17
# 2     0.228189   17
# 3     0.325906   17
# 4     0.378688   17

# %%
len(pd.unique(cons_runs['id']))
# Out:
# 97

# %%
pd.unique(df['Fg_cat'])
# Out:
# array(['High Fg', 'Medium Fg', 'Low Fg'], dtype=object)

# %%
select_chrom = 1
df = cons_runs.loc[cons_runs['chrom']==select_chrom].copy()

df = df.merge(candidates_metrics.loc[candidates_metrics["gen"]==66,["ID","Fg"]],
              left_on="id",right_on="ID",how="left")
df['Fg_cat'] = pd.cut(df['Fg'], bins=3, 
                      labels=['Low Fg','Medium Fg','High Fg'])
df['Fg_cat'] = df['Fg_cat'].astype("str")

df['id'] = df['id'].astype("str")

fig = px.timeline(df, x_start="from", x_end="to", y="id", color="Fg_cat",
                  color_discrete_sequence=["red", "blue", "green"])
fig.update_yaxes(autorange="reversed")

fig.layout.xaxis.type = 'linear'
#fig.data[0].x = df.lengthBps.tolist()
for d in fig.data:
    filt = df['Fg_cat'] == d.name
    d.x = df[filt]['lengthBps'].tolist()

fig.show()
